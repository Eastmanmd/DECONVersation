# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.stats import pearsonr

# %%
import sys

# %%
sys.path.append("/nfs/home/aoku/software/miniconda3/lib/python3.11/site-packages")

# %%
# Load bulk data
cell_lines_bulk = pd.read_csv("/gpfs/commons/groups/compbio/projects/rf_projects/deconv_data/GSE220608/GSE220605_DataMatrix_Mixture_CellLines_Bulk_RNA-seq.csv.gz", index_col=0)

# %%
cell_lines_bulk.head()
# Out:
#           BT474_1  BT474_2  BT474_3  T47D_1  T47D_2  T47D_3  MCF7_1  MCF7_2  \
# A1BG            0        0        3     126     155     139      55      46
# A1BG-AS1        3        2       10     200     160     185     134     187
# A1CF            0        2        0       1       0       1       0       0
# A2M             0        0        0       0       0       0      11      19
# A2M-AS1        13       17        8       0       2       4      25      24
#
#           MCF7_3  Thp1_1  ...  Mix3_c  Mix4_a  Mix4_b  Mix4_c  Mix5_a  Mix5_b  \
# A1BG          65      68  ...      73      39      60      80      76     132
# A1BG-AS1     188      72  ...      93      75      86     122     105     212
# A1CF           0       0  ...       0       1       0       0       0       0
# A2M           12       4  ...       0       1       0       1       1       3
# A2M-AS1       33       0  ...       8       9       6       7       3      20
#
#           Mix5_c  Mix6_a  Mix6_b  Mix6_c
# A1BG          38      90      77      36
# A1BG-AS1     123     111      84      93
# A1CF           4       0       0       0
# A2M           14       1       0       0
# A2M-AS1       14       2       6       4
#
# [5 rows x 36 columns]

# %%
# Load ground truth 
cell_prop = pd.read_excel("/gpfs/commons/groups/compbio/projects/rf_projects/deconv_data/GSE220608/ground_truth.xlsx")

# %%
cell_prop.shape
# Out:
# (36, 6)
