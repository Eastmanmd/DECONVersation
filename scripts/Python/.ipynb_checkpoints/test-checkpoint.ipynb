# %%
import pandas as pd
import numpy as np
from scipy.optimize import nnls
import argparse
import os

# %%
pseudobulk_df = pd.read_csv("/gpfs/commons/groups/compbio/projects/ao_projects/RNA_temp/BLA_20137_B01_EXS_RNA/compbio/data/bulk_bal_for_nnls.csv", index_col=0)
signature_df = pd.read_csv("", index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 pseudobulk_df = pd.read_csv("/gpfs/commons/groups/compbio/projects/ao_projects/RNA_temp/BLA_20137_B01_EXS_RNA/compbio/data/bulk_bal_for_nnls.csv", index_col=0)
# ----> 2 signature_df = pd.read_csv(args.signature, index_col=0)
#
# NameError: name 'args' is not defined
